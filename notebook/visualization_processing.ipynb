# %%
# !echo $PYTHONPATH
# Out:
# :/home/gw/paper_code/src:/home/gw/documents/projects/gagi/src:/home/gw/paper_code/src:/home/gw/documents/projects/gagi/src:/home/gw/documents/projects/peanut_product/peanut_dataset/src:/home/gw/documents/projects/peanut_product/peanut_ml/src

# %%
# %load_ext autoreload
# %autoreload 

from pathlib import Path
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np
from processing import custom_perspective_transform, load_image
from visualization import compare_images
FILE = Path("../data/raw/PXL_20251005_155456998.jpg")

# %matplotlib notebook

# %%
image = load_image(file=FILE)
image_processed = custom_perspective_transform(image=image)
figure = compare_images(image_a=image, image_b=image_processed)
figure
# Out:
# (4032, 3024, 3)
# <div id='05356f63-8003-44d6-afcd-351eff24117d'></div>
